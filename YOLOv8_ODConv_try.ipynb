# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 26.3/166.8 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AXtvn8E5cqIPHd94QNpU")
project = rf.workspace("university-college-london-pmvix").project("nrmm")
dataset = project.version(10).download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.4-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.7 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.2 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 22.2 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.13.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.4)
# Collecting wget (from roboflow)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.2.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (4.8.0.76)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.10.1)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=ec3bf550679a0e74eae6ec8250aec5ecc52252706635645ae52b00830b18669b
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.4 supervision-0.13.0 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in -NRMM-10 to yolov8: 100% [661995826 / 661995826] bytes
# Extracting Dataset Version Zip to -NRMM-10 in yolov8:: 100%|██████████| 8659/8659 [00:01<00:00, 4354.30it/s]

# %% [markdown]
# ##1. Upsampling Layer

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# Out:
# Mounted at /content/drive

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %% [markdown]
# ####A. try conv at different layer

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/yolov8_ODConv_try.yaml")  # build a new model from scratch

# Use the model
model.train(data="/content/-NRMM-10/data.yaml", epochs=50, imgsz=640)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
# Out:
#                    from  n    params  module                                       arguments
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1f64e6bcfad0> in <cell line: 4>()
#       2
#       3 # Load a model
# ----> 4 model = YOLO("/content/yolov8_ODConv_try.yaml")  # build a new model from scratch
#       5
#       6 # Use the model
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in __init__(self, model, type)
#      58         suffix = Path(model).suffix
#      59         if suffix in load_methods:
# ---> 60             {'.pt': self._load, '.yaml': self._new}[suffix](model)
#      61         else:
#      62             raise NotImplementedError(f"'{suffix}' model loading not implemented")
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in _new(self, cfg, verbose)
#      78         self.ModelClass, self.TrainerClass, self.ValidatorClass, self.PredictorClass = \
#      79             self._assign_ops_from_task(self.task)
# ---> 80         self.model = self.ModelClass(cfg_dict, verbose=verbose)  # initialize
#      81         self.cfg = cfg
#      82
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in __init__(self, cfg, ch, nc, verbose)
#     169             LOGGER.info(f"Overriding model.yaml nc={self.yaml['nc']} with nc={nc}")
#     170             self.yaml['nc'] = nc  # override yaml value
# --> 171         self.model, self.save = parse_model(deepcopy(self.yaml), ch=[ch], verbose=verbose)  # model, savelist
#     172         self.names = {i: f'{i}' for i in range(self.yaml['nc'])}  # default names dict
#     173         self.inplace = self.yaml.get('inplace', True)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in parse_model(d, ch, verbose)
#     418     layers, save, c2 = [], [], ch[-1]  # layers, savelist, ch out
#     419     for i, (f, n, m, args) in enumerate(d['backbone'] + d['head']):  # from, number, module, args
# --> 420         m = eval(m) if isinstance(m, str) else m  # eval strings
#     421         for j, a in enumerate(args):
#     422             with contextlib.suppress(NameError):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in <module>
#
# NameError: name 'ODConv_3rd' is not defined

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/train_batch0.jpg', width=600)
# Out:
# /content

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-08-15 03:59:03.226843: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8_up1 summary (fused): 169 layers, 11131002 parameters, 0 gradients, 113.9 GFLOPs
# image 1/163 /content/-NRMM-10/test/images/1063_png.rf.1e2fc921f5474735a2203f61ac9e673d.jpg: 576x640 120.6ms
# image 2/163 /content/-NRMM-10/test/images/1063_png.rf.7f560f145dcee20d6054d3e3f551c7c2.jpg: 576x640 6.9ms
# image 3/163 /content/-NRMM-10/test/images/118_png.rf.12d514584dca38b8e78236588313247d.jpg: 608x640 1 Dump Truck, 119.9ms
# image 4/163 /content/-NRMM-10/test/images/118_png.rf.3ebee2b790e2513b4ee0b5ef8e05d11b.jpg: 608x640 6.9ms
# image 150/163 /content/-NRMM-10/test/images/619_png.rf.8bb6a2abbdd4848de05bac943f37a12b.jpg: 608x640 6.6ms
# image 151/163 /content/-NRMM-10/test/images/641_png.rf.614b4af4809aefbc500a36d115f64816.jpg: 608x640 7.2ms
# image 152/163 /content/-NRMM-10/test/images/669_png.rf.1424a4e470daf660770db4ab0eb3e804.jpg: 608x640 6.7ms
# image 153/163 /content/-NRMM-10/test/images/669_png.rf.1674e0b5d3e81b09f3c1890748a70338.jpg: 608x640 6.9ms
# image 154/163 /content/-NRMM-10/test/images/669_png.rf.36e8d1d5c50be4d6b2bd06d32cd9d0c7.jpg: 608x640 6.6ms
# image 155/163 /content/-NRMM-10/test/images/669_png.rf.51de75008963746feecfc9960f7d48dc.jpg: 608x640 6.5ms
# image 156/163 /content/-NRMM-10/test/images/669_png.rf.5c31b721b01cd2f5215c7ff347f887dc.jpg: 608x640 6.5ms
# image 157/163 /content/-NRMM-10/test/images/669_png.rf.5d5fbfe4e51494a096522123d915a7ae.jpg: 608x640 6.4ms
# image 158/163 /content/-NRMM-10/test/images/669_png.rf.95f54dc97a1d559eb2cac03a0f816879.jpg: 608x640 6.4ms
# image 159/163 /content/-NRMM-10/test/images/669_png.rf.b6e033644fdd35f6e1d0742501aa2a41.jpg: 608x640 1 Haul Truck, 6.7ms
# image 160/163 /content/-NRMM-10/test/images/669_png.rf.f7a2e6db3137bd16a6bef43b6cbd987f.jpg: 608x640 6.6ms
# image 161/163 /content/-NRMM-10/test/images/905_png.rf.01397c4c5825f75e4fbfaccf77827e41.jpg: 640x640 7.6ms
# image 162/163 /content/-NRMM-10/test/images/905_png.rf.50729ce2a7fd7859596793995f46556d.jpg: 640x640 6.9ms
# image 163/163 /content/-NRMM-10/test/images/905_png.rf.e38a79e267e2e7296cd5d2cbe2e0fd51.jpg: 640x640 6.8ms
# Speed: 0.6ms pre-process, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# Let's say we want to create a directory named 'MyColabOutputs'
save_path = '/content/drive/My Drive/YOLOv8_up1'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
import shutil

# Source directory in Colab where your files are saved
src_dir_p = '/content/runs/detect/predict'

# List all files in your source directory
files = os.listdir(src_dir_p)

# Loop through and move each file to the destination directory on Google Drive
for file_name in files:
    full_file_name = os.path.join(src_dir_p, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, save_path)

# Source directory in Colab where your files are saved
src_dir_v = '/content/runs/detect/val'

# List all files in your source directory
files = os.listdir(src_dir_v)

# Loop through and move each file to the destination directory on Google Drive
for file_name in files:
    full_file_name = os.path.join(src_dir_v, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, save_path)

import shutil

# Source directory in Colab where your files are saved
src_dir_t = '/content/runs/detect/train'

# List all files in your source directory
files = os.listdir(src_dir_t)

# Loop through and move each file to the destination directory on Google Drive
for file_name in files:
    full_file_name = os.path.join(src_dir_t, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, save_path)

# %%
#also the model
shutil.copy("/content/runs/detect/train/weights/best.pt", save_path)
shutil.copy("/content/runs/detect/train/weights/last.pt", save_path)
# Out:
# '/content/drive/My Drive/YOLOv8_up1/last.pt'
