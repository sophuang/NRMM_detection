# %% [markdown]
# In this notebook, the source code is used.

# %% [markdown]
# ##1. Clone the source code

# %%
# !git clone https://github.com/sophuang/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 10532, done.
# remote: Counting objects: 100% (692/692), done.
# remote: Compressing objects: 100% (538/538), done.
# remote: Total 10532 (delta 308), reused 457 (delta 150), pack-reused 9840
# Receiving objects: 100% (10532/10532), 5.52 MiB | 17.67 MiB/s, done.
# Resolving deltas: 100% (6889/6889), done.

# %%
# !pip install fastcore -U

# %% [markdown]
# Installing all pre-requested packages

# %%
# !python /content/ultralytics/setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# %cd /content/ultralytics
# Out:
# /content/ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# ##2. Download data

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AXtvn8E5cqIPHd94QNpU")
project = rf.workspace("university-college-london-pmvix").project("nrmm")
dataset = project.version(3).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 7.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=8082ee10394c7882bcaa4e271809d87ee2d7da0a2387e9df3bbd8445830ffc74
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
# ...

# %% [markdown]
# Remember to change the path in the data.yaml file
#
# ---
# test: /content/ultralytics/-NRMM-3/test/images
#
# train: /content/ultralytics/-NRMM-3/train/images
#
# val: /content/ultralytics/-NRMM-3/valid/images

# %% [markdown]
# ##3. Models Training

# %% [markdown]
# ###a. models_t
# Pre-trained weights on COCO dataset is transfered here in models_t

# %%
#pre-trained model from COCO dataset
models_t=YOLO("yolov8s.pt")
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:01<00:00, 14.3MB/s]

# %%
models_t.train(**{'cfg':'/content/ultralytics/ultralytics/cfg/default.yaml'})
# Out:
# cfg file passed. Overriding default params with /content/ultralytics/ultralytics/cfg/default.yaml.
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ###b. models
# New model from scratch with the architecture of yolov8s

# %%
models=YOLO("/content/ultralytics/ultralytics/cfg/models/v8/yolov8.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
# ...

# %%
models.train(**{'cfg':'/content/ultralytics/ultralytics/cfg/default.yaml'})
# Out:
# cfg file passed. Overriding default params with /content/ultralytics/ultralytics/cfg/default.yaml.
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ###c. models_p2
# New model from scratch with the architecture of yolov8 large p2 for small object detection

# %%
models_p2=YOLO("/content/ultralytics/ultralytics/cfg/models/v8/yolov8-p2.yaml")
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
models_p2.train(**{'cfg':'/content/ultralytics/ultralytics/cfg/default.yaml'})
# Out:
# cfg file passed. Overriding default params with /content/ultralytics/ultralytics/cfg/default.yaml.
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ###d. models_p6
# New model from scratch with the architecture of yolov8 large p6 for small object detection

# %%
models_p6=YOLO("/content/ultralytics/ultralytics/cfg/models/v8/yolov8-p6.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    885504  ultralytics.nn.modules.conv.Conv             [256, 384, 3, 2]
# ...

# %%
models_p6.train(**{'cfg':'/content/ultralytics/ultralytics/cfg/default.yaml'})
# Out:
# cfg file passed. Overriding default params with /content/ultralytics/ultralytics/cfg/default.yaml.
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %% [markdown]
# ##Note
# 1.   Using the p6 small object detection version can increase the mAP for certain class: Cement Mixer
# 2.   The highest overall mAP is obtained by models_t witht he transfered weight from COCO dataset

# %% [markdown]
# ##4. Change the IoU

# %% [markdown]
# ###a. WiseIOU
# modify wise iou run those model again

# %%
models_p6_w=YOLO("/content/ultralytics/ultralytics/cfg/models/v8/yolov8-p6.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    885504  ultralytics.nn.modules.conv.Conv             [256, 384, 3, 2]
# ...

# %%
models_p6_w.train(**{'cfg':'/content/ultralytics/ultralytics/cfg/default.yaml'})
# Out:
# cfg file passed. Overriding default params with /content/ultralytics/ultralytics/cfg/default.yaml.
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
results = models_p6_w.predict("/content/-NRMM-3/test/images", save=True, imgsz=640, conf=0.25)
# Out:
# image 1/161 /content/-NRMM-3/test/images/1063_png.rf.d0ab40a638137b53111249a7487280a8.jpg: 640x640 (no detections), 11.9ms
# image 2/161 /content/-NRMM-3/test/images/1063_png.rf.e4507f1e5062c2b37ae1f05bec3b701a.jpg: 640x640 (no detections), 9.3ms
# image 3/161 /content/-NRMM-3/test/images/118_png.rf.1f07ea2a82fa11f0b8970736f011190b.jpg: 640x640 (no detections), 8.5ms
# image 4/161 /content/-NRMM-3/test/images/118_png.rf.724c386fc53ba9d0e0497012f3b49e7d.jpg: 640x640 1 Dump Truck, 1 Excavator, 8.3ms
# image 5/161 /content/-NRMM-3/test/images/118_png.rf.8325ac33ed885e51e9b6fc07ce0f1c2c.jpg: 640x640 (no detections), 8.5ms
# image 6/161 /content/-NRMM-3/test/images/118_png.rf.dd6c5f59074f1b045b39ba2242dc70f0.jpg: 640x640 (no detections), 8.2ms
# image 7/161 /content/-NRMM-3/test/images/131_png.rf.36f88d512a0dc5ab588143e24e85e7c3.jpg: 640x640 2 Dump Trucks, 1 Front loader-Bulldozer, 8.2ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
